# %%
# imports
from matplotlib import pyplot as plt 
import numpy as np  
import pandas as pd

# todo: add the file to colab

# read the data
my_data = pd.read_csv('country-data-no-string-or-onehot.csv')
print(my_data)
# Out:
#      Surface area (km2)  ...  Education: Tertiary gross enrol. ratio (Male)
# 0              652864.0  ...                                      13.300000
# 1               28748.0  ...                                      48.700000
# 2             2381741.0  ...                                      28.900000
# 3                 199.0  ...                                      34.673333
# 4                 468.0  ...                                      34.766667
# ..                  ...  ...                                            ...
# 224               142.0  ...                                      32.640000
# 225            266000.0  ...                                      34.340000
# 226            527968.0  ...                                      13.700000
# 227            752612.0  ...                                       4.500000
# 228            390757.0  ...                                       8.900000
#
# [229 rows x 36 columns]

# %%
# surface area
pd.DataFrame.hist(my_data, column = 'Surface area (km2)', bins = 10)
pd.DataFrame.hist(my_data, column = 'Surface area (km2)', bins = 20)
pd.DataFrame.hist(my_data, column = 'Surface area (km2)', bins = 40)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4928785160>]],
#       dtype=object)

# %%
# rural drinking water
pd.DataFrame.hist(my_data, column = 'Pop. using improved drinking water (rural, %)', bins = 5)
pd.DataFrame.hist(my_data, column = 'Pop. using improved drinking water (rural, %)', bins = 10)
pd.DataFrame.hist(my_data, column = 'Pop. using improved drinking water (rural, %)', bins = 20)

# %%
# urban drinking water

pd.DataFrame.hist(my_data, column = 'Pop. using improved drinking water (urban, %)', bins = 5)
pd.DataFrame.hist(my_data, column = 'Pop. using improved drinking water (urban, %)', bins = 10)
pd.DataFrame.hist(my_data, column = 'Pop. using improved drinking water (urban, %)', bins = 20)

# %%
# <14 Percent Pop
pd.DataFrame.hist(my_data, column = 'Population age distribution (0-14, %)', bins = 5)
pd.DataFrame.hist(my_data, column = 'Population age distribution (0-14, %)', bins = 8)
pd.DataFrame.hist(my_data, column = 'Population age distribution (0-14, %)', bins = 10)
pd.DataFrame.hist(my_data, column = 'Population age distribution (0-14, %)', bins = 15)

# %%
# Urban Percent Pop

pd.DataFrame.hist(my_data, column = 'Urban population (% of total population)', bins = 5)
pd.DataFrame.hist(my_data, column = 'Urban population (% of total population)', bins = 8)
pd.DataFrame.hist(my_data, column = 'Urban population (% of total population)', bins = 10)
pd.DataFrame.hist(my_data, column = 'Urban population (% of total population)', bins = 15)

# %%
# >60 Percent Pop
pd.DataFrame.hist(my_data, column = 'Population age distribution (60+ years, %)', bins = 5)
pd.DataFrame.hist(my_data, column = 'Population age distribution (60+ years, %)', bins = 8)
pd.DataFrame.hist(my_data, column = 'Population age distribution (60+ years, %)', bins = 10)
pd.DataFrame.hist(my_data, column = 'Population age distribution (60+ years, %)', bins = 15)

# %%
# >60 Percent Pop
pd.DataFrame.hist(my_data, column = 'Population density (per km2, 2017)', bins = 5)
pd.DataFrame.hist(my_data, column = 'Population density (per km2, 2017)', bins = 8)
pd.DataFrame.hist(my_data, column = 'Population density (per km2, 2017)', bins = 10)
pd.DataFrame.hist(my_data, column = 'Population density (per km2, 2017)', bins = 25)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f49290ca048>]],
#       dtype=object)

# %%
covid_data = pd.read_csv('CovidCasesNoBlanks.csv')

pd.DataFrame.hist(covid_data, column = '5', bins = 25)
pd.DataFrame.hist(covid_data, column = '25', bins = 25)
pd.DataFrame.hist(covid_data, column = '50', bins = 25)

# %%
my_data.corr(method='pearson')
# Out:
#                                                     Surface area (km2)  ...  Education: Tertiary gross enrol. ratio (Male)
# Surface area (km2)                                            1.000000  ...                                       0.162493
# Population in thousands (2017)                                0.454829  ...                                       0.028518
# Population density (per km2, 2017)                           -0.058039  ...                                       0.101264
# GDP: Gross domestic product (million current US$)             0.550457  ...                                       0.235860
# GDP growth rate (annual %, const. 2005 prices)               -0.063901  ...                                      -0.109978
# GDP per capita (current US$)                                  0.008118  ...                                       0.360807
# Economy: Agriculture (% of GVA)                              -0.046961  ...                                      -0.461377
# Economy: Industry (% of GVA)                                  0.107409  ...                                      -0.012938
# Economy: Services and other activity (% of GVA)              -0.055044  ...                                       0.359726
# Employment: Agriculture (% of employed)                      -0.033764  ...                                      -0.547976
# Employment: Industry (% of employed)                          0.091101  ...                                       0.351220
# Employment: Services (% of employed)                          0.010576  ...                                       0.509135
# Unemployment (% of labour force)                             -0.087763  ...                                      -0.035268
# Agricultural production index (2004-2006=100)                 0.108641  ...                                      -0.295430
# Food production index (2004-2006=100)                         0.105530  ...                                      -0.303778
# International trade: Exports (million US$)                    0.487083  ...                                       0.337355
# International trade: Imports (million US$)                    0.490336  ...                                       0.338297
# Population growth rate (average annual %)                    -0.013234  ...                                      -0.438198
# Urban population (% of total population)                      0.093520  ...                                       0.492789
# Urban population growth rate (average annual %)               0.001153  ...                                      -0.515627
# Population age distribution (0-14, %)                        -0.055487  ...                                      -0.640405
# Population age distribution (60+ years, %)                    0.058498  ...                                       0.661088
# Health: Total expenditure (% of GDP)                          0.076563  ...                                       0.344029
# Health: Physicians (per 1000 pop.)                            0.034147  ...                                       0.569663
# Education: Government expenditure (% of GDP)                 -0.003889  ...                                       0.162979
# Pop. using improved drinking water (urban, %)                 0.001616  ...                                       0.555789
# Pop. using improved drinking water (rural, %)                -0.041052  ...                                       0.579926
# Pop. using improved sanitation facilities (urba...           -0.136284  ...                                      -0.235065
# Life expectancy at birth (Female)                             0.015461  ...                                       0.651740
# Life expectancy at birth (Male)                              -0.003868  ...                                       0.613839
# Education: Primary gross enrol. ratio (Female)                0.000901  ...                                       0.012192
# Education: Primary gross enrol. ratio (Male)                 -0.012252  ...                                      -0.118852
# Education: Secondary gross enrol. ratio (Female)              0.044379  ...                                       0.641229
# Education: Secondary gross enrol. ratio (Male)                0.073345  ...                                       0.692725
# Education: Tertiary gross enrol. ratio (Female)               0.138346  ...                                       0.925538
# Education: Tertiary gross enrol. ratio (Male)                 0.162493  ...                                       1.000000
#
# [36 rows x 36 columns]
